# %%
import pandas as pd #importação da biblioteca Pandas (análise dos dados) e a apelidando como pd.

# %%
cor = pd.read_csv('cor_raca_ocupacao.csv', delimiter = ';', encoding='latin-1') #lendo a planilha 'cor_raca_ocupacao_pb.csv'
#e salvando na variável cor.

# %%
cor.head()
# Out:
#    UF Cor/Raça           Ocupação  Quantitativo Porcentagem (%)  Unnamed: 5
# 0  PB  Amarela           Advogado             1           33,33         NaN
# 1  PB  Amarela  Assistente Social             1           33,33         NaN
# 2  PB  Amarela         Empresário             1           33,33         NaN
# 3  PB   Branca      Administrador            10            3,48         NaN
# 4  PB   Branca           Advogado            26            9,06         NaN

# %%
cor.drop(['Porcentagem (%)', 'Unnamed: 5', 'UF'], axis=1, inplace=True) #apagando o que eu não quero, axis=1(colunas)

# %%
cor.head() #5 primeiras linhas da nova tabela, com as colunas acima excluídas.
# Out:
#   Cor/Raça           Ocupação  Quantitativo
# 0  Amarela           Advogado             1
# 1  Amarela  Assistente Social             1
# 2  Amarela         Empresário             1
# 3   Branca      Administrador            10
# 4   Branca           Advogado            26

# %%
cor['Cor/Raça'].unique() #me mostre o que tem, sem repetir
# Out:
# array(['Amarela', 'Branca', 'Indígena', 'Parda', 'Preta'], dtype=object)

# %%
Amarela = cor.loc[cor['Cor/Raça'] == 'Amarela'] #selecionando apenas cor/raça Amarela

# %%
Amarela.sort_values(by = "Quantitativo", ascending = False) #ordenar a coluna Quantitativa em ordem decrescente.
# Out:
#   Cor/Raça           Ocupação  Quantitativo
# 0  Amarela           Advogado             1
# 1  Amarela  Assistente Social             1
# 2  Amarela         Empresário             1

# %%
Branca = cor.loc[cor['Cor/Raça'] == 'Branca'] #selecionando apenas cor/raça Branca

# %%
Branca.sort_values(by = 'Quantitativo', ascending = False) #ordenando a coluna 'Quantitativa' em ordem decrescente.
# Out:
#    Cor/Raça                                           Ocupação  Quantitativo
# 37   Branca                                             Outros            35
# 23   Branca                                         Empresário            29
# 4    Branca                                           Advogado            26
# 20   Branca                                           Deputado            23
# 25   Branca     Estudante, Bolsista, Estagiário e Assemelhados            17
# 33   Branca                                             Médico            13
# 16   Branca                                        Comerciante            11
# 3    Branca                                      Administrador            10
# 50   Branca                          Servidor Público Estadual            10
# 41   Branca                                   Policial Militar             8
# 45   Branca                       Professor de Ensino Superior             7
# ...

# %%
Parda = cor.loc[cor['Cor/Raça'] == 'Parda'] #selecionando apenas Cor/Raça Parda

# %%
Parda.sort_values(by = 'Quantitativo', ascending= False) #ordenando a coluna como mostrado anteriormente para as outras raças.
# Out:
#     Cor/Raça                                           Ocupação  Quantitativo
# 93     Parda                                             Outros            42
# 79     Parda                                         Empresário            21
# 95     Parda                                   Policial Militar            15
# 75     Parda                                           Deputado            11
# 108    Parda                          Servidor Público Estadual             6
# 110    Parda                         Servidor Público Municipal             6
# 77     Parda                                       Dona de Casa             6
# 80     Parda     Estudante, Bolsista, Estagiário e Assemelhados             6
# 99     Parda                          Professor de Ensino Médio             6
# 115    Parda  Vendedor Pracista, Representante, Caixeiro-Via...             5
# 116    Parda                                           Vereador             5
# ...

# %%
Preta = cor.loc[cor['Cor/Raça'] == 'Preta']

# %%
Preta.sort_values(by = 'Quantitativo', ascending = False)
# Out:
#     Cor/Raça                                           Ocupação  Quantitativo
# 134    Preta                                             Outros             6
# 138    Preta                       Professor de Ensino Superior             3
# 136    Preta                    Professor de Ensino Fundamental             3
# 119    Preta                                      Administrador             2
# 135    Preta                                   Policial Militar             2
# 142    Preta  Técnico Contabilidade, Estatística, Economia D...             2
# 125    Preta                                           Deputado             2
# 127    Preta                                       Dona de Casa             2
# 128    Preta     Estudante, Bolsista, Estagiário e Assemelhados             2
# 137    Preta                          Professor de Ensino Médio             2
# 120    Preta                                           Advogado             2
# ...

# %%
Indígena = cor.loc[cor['Cor/Raça'] == 'Indígena']

# %%
Indígena.sort_values(by = 'Quantitativo', ascending='False')
# Out:
#     Cor/Raça Ocupação  Quantitativo
# 58  Indígena   Outros             1
